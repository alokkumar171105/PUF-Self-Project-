# %%
import numpy as np

# %%
x =[ 3, 9 ,5 , 8, 11, -15, -7.5]
z = -np.abs(x)
w = np.argsort(z)
y = np.argsort(-np.abs(x))[:3]

print(z)
print(w)
print(y)
# Out:
# [ -3.   -9.   -5.   -8.  -11.  -15.   -7.5]
# [5 4 1 3 6 2 0]
# [5 4 1]
